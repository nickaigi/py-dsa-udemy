# %% [markdown]
# # Introduction to Jupyter Notebooks

# %%
print("Hello World")
# Out:
# Hello World

# %%
from math import sqrt

# %%
s = 'hello'

# %%
s
# Out:
# 'hello'

# %%
s.upper()
# Out:
# 'HELLO'

# %%
s.capitalize()
# Out:
# 'Hello'

# %% [markdown]
# ### writing in Latex
#
# $$ \LaTeX $$
# $$ example: \sqrt x $$
